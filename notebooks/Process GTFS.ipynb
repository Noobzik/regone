# %% [markdown]
# This notebook is maded for exploration purposes of the GTFS Dataset.
# It is also used to moount an Data Model

# %%
import pandas as pd

# %%
def import_gtfs(gtfs_path, busiest_date = True):
    import warnings
    warnings.filterwarnings("ignore")
    import os
    import pandas as pd
    import zipfile

    try:
        import partridge as ptg 
    except ImportError as e:
        os.system('pip install partridge')
        import partridge as ptg

    try:
        import geopandas as gpd
    except ImportError as e:
        os.system('pip install geopandas')
        import geopandas as gpd
    # Partridge to read the feed
    # service_ids = pd.read_csv(gtfs_path + '/trips.txt')['service_id'].unique()
    # service_ids = frozenset(tuple(service_ids))
        
    if busiest_date:
        service_ids = ptg.read_busiest_date(gtfs_path)[1]
    else:
        with zipfile.ZipFile(gtfs_path) as myzip:
            myzip.extract("trips.txt")
        service_ids = pd.read_csv('trips.txt')['service_id'].unique()
        service_ids = frozenset(tuple(service_ids))
        os.remove('trips.txt')
        
    view = {'trips.txt': {'service_id': service_ids}}
    
    feed = ptg.load_geo_feed(gtfs_path, view)
    
    routes = feed.routes
    trips = feed.trips
    stop_times = feed.stop_times
    stops = feed.stops
    shapes = feed.shapes
    
    # Get routes info in trips
    # The GTFS feed might be missing some of the keys, e.g. direction_id or shape_id.
    # To allow processing incomplete GTFS data, we must reindex instead:
    # https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
    # This will add NaN for any missing columns.
    trips = pd.merge(trips, routes, how='left').reindex(columns=['trip_id', 'route_id',
                                                        'service_id','trip_headsign', 'trip_short_name', 'direction_id','shape_id'])
#    ["route_id","service_id","trip_id","trip_headsign","trip_short_name","direction_id","block_id","shape_id","wheelchair_accessible","bikes_allowed"]
    
    
    # Get trips, routes and stops info in stop_times
    stop_times = pd.merge(stop_times, trips, how='left') 
    stop_times = pd.merge(stop_times, stops, how='left')
    # stop_times needs to be geodataframe if we want to do geometry operations
    stop_times = gpd.GeoDataFrame(stop_times, geometry='geometry')
    
    return routes, stops, stop_times, trips, shapes

# %%
# Import GTFS
gtfs_path = "../data/external/transilien-gtfs.zip"

# %%
routes, stops, stop_times, trips, shapes = import_gtfs(gtfs_path)

# %%
trips
# Out:
#                                                 trip_id     route_id  \
# 0     IDFM:TN:SNCF:52c63590-6112-44af-8e30-a50676e0291f  IDFM:C01727
# 1     IDFM:TN:SNCF:58c81c89-786e-4786-a777-634c9b9dfd1c  IDFM:C01727
# 2     IDFM:TN:SNCF:069613e8-f76b-4a90-aef3-c3ca04399a91  IDFM:C01727
# 3     IDFM:TN:SNCF:dfcd1c09-5d46-40d0-9113-4b336019b401  IDFM:C01727
# 4     IDFM:TN:SNCF:52754d1f-f621-465d-a6f2-557421393d83  IDFM:C01727
# ...                                                 ...          ...
# 7157  IDFM:TN:SNCF:5a2e232d-c7e0-4f84-b569-b377c386a621  IDFM:C01741
# 7158  IDFM:TN:SNCF:abf7198b-2123-4b7e-8dc4-ff25e1938560  IDFM:C01741
# 7159  IDFM:TN:SNCF:a6bbbe4e-6c25-4923-893d-446c196f35a0  IDFM:C01727
# 7160  IDFM:TN:SNCF:10d16abb-d2c4-4159-92cd-4c2e6c1fab65  IDFM:C01851
# 7161  IDFM:TN:SNCF:53e33c3f-1628-4c49-9c05-21a148c8f75b  IDFM:C01851
#
#                                         service_id     trip_headsign  \
# 0     IDFM:TN:00c39053-c1be-30e2-ad5c-7c7ee9a80ffb              ROMI
# 1     IDFM:TN:00c39053-c1be-30e2-ad5c-7c7ee9a80ffb              ZORA
# 2     IDFM:TN:00c39053-c1be-30e2-ad5c-7c7ee9a80ffb              JILL
# 3     IDFM:TN:00c39053-c1be-30e2-ad5c-7c7ee9a80ffb              ROMI
# 4     IDFM:TN:00c39053-c1be-30e2-ad5c-7c7ee9a80ffb              ZORA
# ...                                            ...               ...
# 7157                                  IDFM:TN:9062              VERI
# 7158                                  IDFM:TN:9096              DEFI
# 7159  IDFM:TN:dd4edddc-bd73-346a-bde7-9d1aedaee37f              ROMI
# 7160  IDFM:TN:ea9dc28e-9a32-35d3-a46e-d3e3154a0eba  Paris Austerlitz
# 7161  IDFM:TN:ea9dc28e-9a32-35d3-a46e-d3e3154a0eba  Paris Austerlitz
#
#      trip_short_name  direction_id shape_id
# 0             148101             0      NaN
# 1             147100             0      NaN
# 2             147213             0      NaN
# 3             140189             0      NaN
# 4             143546             0      NaN
# ...              ...           ...      ...
# 7157          164303             0      NaN
# 7158          164350             0      NaN
# 7159          140183             0      NaN
# 7160         7917002             0      NaN
# 7161         7917003             0      NaN
#
# [7162 rows x 7 columns]

# %%
routes_line = "IDFM:C01743"

# %%
rer_b_trips = trips[trips.route_id == routes_line]

# %%
rer_b_trips = rer_b_trips.reset_index(drop=True)
rer_b_trips[rer_b_trips.trip_id == "IDFM:TN:SNCF:4794d582-f8b6-4f86-b86c-64df751bc3c7"]
# Out:
#                                                trip_id     route_id  \
# 131  IDFM:TN:SNCF:4794d582-f8b6-4f86-b86c-64df751bc3c7  IDFM:C01743
#
#         service_id trip_headsign trip_short_name  direction_id shape_id
# 131  IDFM:TN:14244          EPAF          EPOI81             0      NaN

# %%
pd.set_option('display.max_columns', None)

# %%
df = stop_times.merge(rer_b_trips, on=['trip_id', 'route_id', 'service_id', 'trip_headsign', 'trip_short_name', 'direction_id', 'shape_id'])

# %%
df["temps_darret"] = df["departure_time"] - df["arrival_time"]

# %%
a = df["trip_id"].unique()

# %%
d = 0
for trip in a:
    if d == 500:
        b = df[df.trip_id==trip]
        break
    d = d + 1

# %%
b
# Out:
#                                                  trip_id  arrival_time  \
# 13083  IDFM:TN:SNCF:1c49e953-0d64-4dbe-90b1-2a7abc0d6243       53459.0
# 13084  IDFM:TN:SNCF:1c49e953-0d64-4dbe-90b1-2a7abc0d6243       53564.0
# 13085  IDFM:TN:SNCF:1c49e953-0d64-4dbe-90b1-2a7abc0d6243       53672.0
# 13086  IDFM:TN:SNCF:1c49e953-0d64-4dbe-90b1-2a7abc0d6243       53757.0
# 13087  IDFM:TN:SNCF:1c49e953-0d64-4dbe-90b1-2a7abc0d6243       53873.0
# 13088  IDFM:TN:SNCF:1c49e953-0d64-4dbe-90b1-2a7abc0d6243       53984.0
# 13089  IDFM:TN:SNCF:1c49e953-0d64-4dbe-90b1-2a7abc0d6243       54092.0
# 13090  IDFM:TN:SNCF:1c49e953-0d64-4dbe-90b1-2a7abc0d6243       54201.0
# 13091  IDFM:TN:SNCF:1c49e953-0d64-4dbe-90b1-2a7abc0d6243       54370.0
# 13092  IDFM:TN:SNCF:1c49e953-0d64-4dbe-90b1-2a7abc0d6243       54470.0
# 13093  IDFM:TN:SNCF:1c49e953-0d64-4dbe-90b1-2a7abc0d6243       54593.0
# 13094  IDFM:TN:SNCF:1c49e953-0d64-4dbe-90b1-2a7abc0d6243       54700.0
# 13095  IDFM:TN:SNCF:1c49e953-0d64-4dbe-90b1-2a7abc0d6243       54796.0
# 13096  IDFM:TN:SNCF:1c49e953-0d64-4dbe-90b1-2a7abc0d6243       54936.0
# 13097  IDFM:TN:SNCF:1c49e953-0d64-4dbe-90b1-2a7abc0d6243       55103.0
# 13098  IDFM:TN:SNCF:1c49e953-0d64-4dbe-90b1-2a7abc0d6243       55229.0
# 13099  IDFM:TN:SNCF:1c49e953-0d64-4dbe-90b1-2a7abc0d6243       55349.0
# 13100  IDFM:TN:SNCF:1c49e953-0d64-4dbe-90b1-2a7abc0d6243       55560.0
# 13101  IDFM:TN:SNCF:1c49e953-0d64-4dbe-90b1-2a7abc0d6243       57210.0
# 13102  IDFM:TN:SNCF:1c49e953-0d64-4dbe-90b1-2a7abc0d6243       57410.0
#
#        departure_time                         stop_id  stop_sequence  \
# 13083         53459.0   IDFM:monomodalStopPlace:58774              0
# 13084         53584.0   IDFM:monomodalStopPlace:47940              1
# 13085         53692.0   IDFM:monomodalStopPlace:43228              2
# 13086         53777.0   IDFM:monomodalStopPlace:43124              3
# 13087         53913.0   IDFM:monomodalStopPlace:43066              4
# 13088         54014.0   IDFM:monomodalStopPlace:46007              5
# 13089         54112.0   IDFM:monomodalStopPlace:43177              6
# 13090         54251.0   IDFM:monomodalStopPlace:43097              7
# 13091         54400.0   IDFM:monomodalStopPlace:44493              8
# 13092         54500.0   IDFM:monomodalStopPlace:43067              9
# 13093         54623.0   IDFM:monomodalStopPlace:43607             10
# 13094         54730.0   IDFM:monomodalStopPlace:45877             11
# 13095         54826.0  IDFM:monomodalStopPlace:473843             12
# 13096         54986.0  IDFM:monomodalStopPlace:473890             13
# 13097         55133.0   IDFM:monomodalStopPlace:43833             14
# 13098         55269.0   IDFM:monomodalStopPlace:44877             15
# 13099         55380.0   IDFM:monomodalStopPlace:45102             16
# 13100         55620.0  IDFM:monomodalStopPlace:462394             17
# 13101         57270.0  IDFM:monomodalStopPlace:462398             18
# 13102         57410.0  IDFM:monomodalStopPlace:473364             19
#
#        pickup_type drop_off_type local_zone_id stop_headsign  timepoint  \
# 13083            0             1           NaN           NaN          1
# 13084            0             0           NaN           NaN          1
# 13085            0             0           NaN           NaN          1
# 13086            0             0           NaN           NaN          1
# 13087            0             0           NaN           NaN          1
# 13088            0             0           NaN           NaN          1
# 13089            0             0           NaN           NaN          1
# 13090            0             0           NaN           NaN          1
# 13091            0             0           NaN           NaN          1
# 13092            0             0           NaN           NaN          1
# 13093            0             0           NaN           NaN          1
# 13094            0             0           NaN           NaN          1
# 13095            0             0           NaN           NaN          1
# 13096            0             0           NaN           NaN          1
# 13097            0             0           NaN           NaN          1
# 13098            0             0           NaN           NaN          1
# 13099            0             0           NaN           NaN          1
# 13100            0             0           NaN           NaN          1
# 13101            0             0           NaN           NaN          1
# 13102            1             0           NaN           NaN          1
#
#           route_id     service_id trip_headsign trip_short_name  direction_id  \
# 13083  IDFM:C01743  IDFM:TN:32272          ERIC          ERIO79             0
# 13084  IDFM:C01743  IDFM:TN:32272          ERIC          ERIO79             0
# 13085  IDFM:C01743  IDFM:TN:32272          ERIC          ERIO79             0
# 13086  IDFM:C01743  IDFM:TN:32272          ERIC          ERIO79             0
# 13087  IDFM:C01743  IDFM:TN:32272          ERIC          ERIO79             0
# 13088  IDFM:C01743  IDFM:TN:32272          ERIC          ERIO79             0
# 13089  IDFM:C01743  IDFM:TN:32272          ERIC          ERIO79             0
# 13090  IDFM:C01743  IDFM:TN:32272          ERIC          ERIO79             0
# 13091  IDFM:C01743  IDFM:TN:32272          ERIC          ERIO79             0
# 13092  IDFM:C01743  IDFM:TN:32272          ERIC          ERIO79             0
# 13093  IDFM:C01743  IDFM:TN:32272          ERIC          ERIO79             0
# 13094  IDFM:C01743  IDFM:TN:32272          ERIC          ERIO79             0
# 13095  IDFM:C01743  IDFM:TN:32272          ERIC          ERIO79             0
# 13096  IDFM:C01743  IDFM:TN:32272          ERIC          ERIO79             0
# 13097  IDFM:C01743  IDFM:TN:32272          ERIC          ERIO79             0
# 13098  IDFM:C01743  IDFM:TN:32272          ERIC          ERIO79             0
# 13099  IDFM:C01743  IDFM:TN:32272          ERIC          ERIO79             0
# 13100  IDFM:C01743  IDFM:TN:32272          ERIC          ERIO79             0
# 13101  IDFM:C01743  IDFM:TN:32272          ERIC          ERIO79             0
# 13102  IDFM:C01743  IDFM:TN:32272          ERIC          ERIO79             0
#
#       shape_id stop_code                                  stop_name stop_desc  \
# 13083      NaN       NaN                          Massy - Palaiseau       NaN
# 13084      NaN       NaN                          Massy - Verrières       NaN
# 13085      NaN       NaN                              Les Baconnets       NaN
# 13086      NaN       NaN                          Fontaine Michalon       NaN
# 13087      NaN       NaN                                     Antony       NaN
# 13088      NaN       NaN                          La Croix de Berny       NaN
# 13089      NaN       NaN                             Parc de Sceaux       NaN
# 13090      NaN       NaN                             Bourg-la-Reine       NaN
# 13091      NaN       NaN                                    Bagneux       NaN
# 13092      NaN       NaN                           Arcueil - Cachan       NaN
# 13093      NaN       NaN                                    Laplace       NaN
# 13094      NaN       NaN                                   Gentilly       NaN
# 13095      NaN       NaN                         Cité Universitaire       NaN
# 13096      NaN       NaN                          Denfert-Rochereau       NaN
# 13097      NaN       NaN                                 Luxembourg       NaN
# 13098      NaN       NaN                    Saint-Michel Notre-Dame       NaN
# 13099      NaN       NaN                        Châtelet les Halles       NaN
# 13100      NaN       NaN                               Gare du Nord       NaN
# 13101      NaN       NaN          Aéroport CDG 1 (Terminal 3) - RER       NaN
# 13102      NaN       NaN  Aéroport Charles de Gaulle 2 (Terminal 2)       NaN
#
#       zone_id stop_url  location_type parent_station stop_timezone level_id  \
# 13083       4      NaN              0     IDFM:63244           NaN      NaN
# 13084       4      NaN              0     IDFM:63320           NaN      NaN
# 13085       4      NaN              0     IDFM:69622           NaN      NaN
# 13086       4      NaN              0     IDFM:69647           NaN      NaN
# 13087       3      NaN              0     IDFM:69759           NaN      NaN
# 13088       3      NaN              0     IDFM:69813           NaN      NaN
# 13089       3      NaN              0     IDFM:69906           NaN      NaN
# 13090       3      NaN              0     IDFM:70033           NaN      NaN
# 13091       3      NaN              0     IDFM:70210           NaN      NaN
# 13092       3      NaN              0     IDFM:70263           NaN      NaN
# 13093       2      NaN              0     IDFM:70427           NaN      NaN
# 13094       2      NaN              0     IDFM:70543           NaN      NaN
# 13095       1      NaN              0     IDFM:70623           NaN      NaN
# 13096       1      NaN              0     IDFM:71056           NaN      NaN
# 13097       1      NaN              0     IDFM:71161           NaN      NaN
# 13098       1      NaN              0     IDFM:73620           NaN      NaN
# 13099       1      NaN              0    IDFM:474151           NaN      NaN
# 13100       1      NaN              0     IDFM:71410           NaN      NaN
# 13101       5      NaN              0     IDFM:73596           NaN      NaN
# 13102       5      NaN              0     IDFM:73699           NaN      NaN
#
#        wheelchair_boarding platform_code                  geometry  \
# 13083                    0           NaN  POINT (2.25877 48.72552)
# 13084                    0           NaN  POINT (2.27395 48.73499)
# 13085                    0           NaN  POINT (2.28811 48.73985)
# 13086                    0           NaN  POINT (2.29596 48.74305)
# 13087                    0           NaN  POINT (2.30089 48.75463)
# 13088                    0           NaN  POINT (2.30421 48.76172)
# 13089                    0           NaN  POINT (2.30993 48.76972)
# 13090                    0           NaN  POINT (2.31228 48.78026)
# 13091                    0           NaN  POINT (2.32201 48.79334)
# 13092                    0           NaN  POINT (2.32809 48.79870)
# 13093                    0           NaN  POINT (2.33434 48.80836)
# 13094                    0           NaN  POINT (2.34093 48.81523)
# 13095                    0           NaN  POINT (2.33886 48.82151)
# 13096                    0           NaN  POINT (2.33322 48.83319)
# 13097                    0           NaN  POINT (2.33981 48.84543)
# 13098                    0           NaN  POINT (2.34496 48.85302)
# 13099                    0           NaN  POINT (2.34698 48.86175)
# 13100                    0           NaN  POINT (2.35669 48.88231)
# 13101                    0           NaN  POINT (2.56141 49.00979)
# 13102                    0           NaN  POINT (2.57098 49.00415)
#
#        temps_darret
# 13083           0.0
# 13084          20.0
# 13085          20.0
# 13086          20.0
# 13087          40.0
# 13088          30.0
# 13089          20.0
# 13090          50.0
# 13091          30.0
# 13092          30.0
# 13093          30.0
# 13094          30.0
# 13095          30.0
# 13096          50.0
# 13097          30.0
# 13098          40.0
# 13099          31.0
# 13100          60.0
# 13101          60.0
# 13102           0.0

# %%
relation = pd.read_csv("../data/processed/relation_ordre_RER_B.csv", sep=';', names=["Station_name", "Station_Order"])
d = relation.set_index('Station_name').T.to_dict('index')
d = d["Station_Order"]

# %%
def find_direction(relation: dict, d1: str, d2:str) -> int:
    if (relation[d1] < relation[d2]):
        return 0 # Sud
    else:
        return 1 # Nord

# %%
column_names = ["trip_id", "trip_line", "trip_headsign", "trip_short_name", "destination", "destination_id" ,"origin", "origin_id", "time_departure", "arrival", "arrival_id", "time_arrival", "time_travelled"] # Time difference
cleaned_df = pd.DataFrame(columns = column_names)
import time

# %%
cleaned_df
# Out:
# Empty DataFrame
# Columns: [trip_id, trip_line, trip_headsign, trip_short_name, destination, destination_id, origin, origin_id, time_departure, arrival, arrival_id, time_arrival, time_travelled]
# Index: []

# %%
a = df["trip_id"].unique()
start_time = time.time()
current = 0
for journeys in a:
    test = df[df.trip_id==journeys].reset_index(drop=True)
    for i in range(1, len(test)):
        if i == 1:
            start = test.loc[i-1, 'stop_name']
            destination = test.loc[len(test)-1, 'stop_name']
            destination_id = test.loc[len(test)-1, 'parent_station']
            direction = find_direction(d, test.loc[i-1, 'stop_name'], destination)
            
        trip_id = test.loc[i, 'trip_id']
        trip_line = test.loc[i,'route_id']
        trip_headsign = test.loc[i-1, "trip_headsign"]
        trip_short_name =test.loc[i-1, "trip_short_name"]
        origin = test.loc[i-1, 'stop_name']
        origin_id = test.loc[i-1, 'parent_station']
        time_departure = test.loc[i-1, 'departure_time']
        
        arrival = test.loc[i, 'stop_name']
        arrival_id = test.loc[i, 'parent_station']
        time_arrival = test.loc[i, 'arrival_time']
        time_travelled = time_arrival - time_departure

        cleaned_df = cleaned_df.append({
            "trip_id": trip_id, 
            "trip_line":trip_line,
            "trip_headsign": trip_headsign,
            "trip_short_name": trip_short_name,
            "destination": destination,
            "destination_id": destination_id,
            "origin": origin,
            "origin_id": origin_id,
            "time_departure":time_departure,
            "arrival": arrival,
            "arrival_id": arrival_id,
            "time_arrival": time_arrival,
            "time_travelled":time_travelled,
            "direction":direction},
            ignore_index=True)

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 44.016666889190674 seconds ---

# %%
cleaned_df.tail(10)
# Out:
#                                                  trip_id    trip_line  \
# 13824  IDFM:TN:SNCF:088751b1-4273-4ad5-b680-84af98980599  IDFM:C01743
# 13825  IDFM:TN:SNCF:088751b1-4273-4ad5-b680-84af98980599  IDFM:C01743
# 13826  IDFM:TN:SNCF:088751b1-4273-4ad5-b680-84af98980599  IDFM:C01743
# 13827  IDFM:TN:SNCF:088751b1-4273-4ad5-b680-84af98980599  IDFM:C01743
# 13828  IDFM:TN:SNCF:088751b1-4273-4ad5-b680-84af98980599  IDFM:C01743
# 13829  IDFM:TN:SNCF:088751b1-4273-4ad5-b680-84af98980599  IDFM:C01743
# 13830  IDFM:TN:SNCF:088751b1-4273-4ad5-b680-84af98980599  IDFM:C01743
# 13831  IDFM:TN:SNCF:088751b1-4273-4ad5-b680-84af98980599  IDFM:C01743
# 13832  IDFM:TN:SNCF:088751b1-4273-4ad5-b680-84af98980599  IDFM:C01743
# 13833  IDFM:TN:SNCF:088751b1-4273-4ad5-b680-84af98980599  IDFM:C01743
#
#       trip_headsign trip_short_name               destination destination_id  \
# 13824          PIER          PILE96  Saint-Rémy-lès-Chevreuse     IDFM:62978
# 13825          PIER          PILE96  Saint-Rémy-lès-Chevreuse     IDFM:62978
# 13826          PIER          PILE96  Saint-Rémy-lès-Chevreuse     IDFM:62978
# 13827          PIER          PILE96  Saint-Rémy-lès-Chevreuse     IDFM:62978
# 13828          PIER          PILE96  Saint-Rémy-lès-Chevreuse     IDFM:62978
# 13829          PIER          PILE96  Saint-Rémy-lès-Chevreuse     IDFM:62978
# 13830          PIER          PILE96  Saint-Rémy-lès-Chevreuse     IDFM:62978
# 13831          PIER          PILE96  Saint-Rémy-lès-Chevreuse     IDFM:62978
# 13832          PIER          PILE96  Saint-Rémy-lès-Chevreuse     IDFM:62978
# 13833          PIER          PILE96  Saint-Rémy-lès-Chevreuse     IDFM:62978
#
#                      origin   origin_id time_departure  \
# 13824     Massy - Palaiseau  IDFM:63244        80212.0
# 13825             Palaiseau  IDFM:63175        80344.0
# 13826  Palaiseau - Villebon  IDFM:63067        80454.0
# 13827                Lozère  IDFM:63029        80612.0
# 13828            Le Guichet  IDFM:63025        80738.0
# 13829           Orsay Ville  IDFM:62892        80871.0
# 13830      Bures-sur-Yvette  IDFM:62851        80988.0
# 13831        La Hacquinière  IDFM:62825        81100.0
# 13832        Gif-sur-Yvette  IDFM:62890        81213.0
# 13833  Courcelle-sur-Yvette  IDFM:62951        81401.0
#
#                         arrival  arrival_id time_arrival time_travelled  \
# 13824                 Palaiseau  IDFM:63175      80314.0          102.0
# 13825      Palaiseau - Villebon  IDFM:63067      80424.0           80.0
# 13826                    Lozère  IDFM:63029      80582.0          128.0
# 13827                Le Guichet  IDFM:63025      80708.0           96.0
# 13828               Orsay Ville  IDFM:62892      80831.0           93.0
# 13829          Bures-sur-Yvette  IDFM:62851      80958.0           87.0
# 13830            La Hacquinière  IDFM:62825      81070.0           82.0
# 13831            Gif-sur-Yvette  IDFM:62890      81183.0           83.0
# 13832      Courcelle-sur-Yvette  IDFM:62951      81371.0          158.0
# 13833  Saint-Rémy-lès-Chevreuse  IDFM:62978      81543.0          142.0
#
#        direction
# 13824        0.0
# 13825        0.0
# 13826        0.0
# 13827        0.0
# 13828        0.0
# 13829        0.0
# 13830        0.0
# 13831        0.0
# 13832        0.0
# 13833        0.0

# %%
cleaned_df = cleaned_df.astype({"time_departure":'int', "time_arrival":'int', 'time_travelled':'int', 'direction':'int'})

# %%
cleaned_df[cleaned_df.trip_headsign=="USER"]
# Out:
#                                                  trip_id    trip_line  \
# 9793   IDFM:TN:SNCF:bd30df92-db61-4136-9a3d-e8a5a28b79d4  IDFM:C01743
# 9794   IDFM:TN:SNCF:bd30df92-db61-4136-9a3d-e8a5a28b79d4  IDFM:C01743
# 9795   IDFM:TN:SNCF:bd30df92-db61-4136-9a3d-e8a5a28b79d4  IDFM:C01743
# 9796   IDFM:TN:SNCF:bd30df92-db61-4136-9a3d-e8a5a28b79d4  IDFM:C01743
# 9797   IDFM:TN:SNCF:bd30df92-db61-4136-9a3d-e8a5a28b79d4  IDFM:C01743
# 9798   IDFM:TN:SNCF:bd30df92-db61-4136-9a3d-e8a5a28b79d4  IDFM:C01743
# 9799   IDFM:TN:SNCF:bd30df92-db61-4136-9a3d-e8a5a28b79d4  IDFM:C01743
# 9800   IDFM:TN:SNCF:bd30df92-db61-4136-9a3d-e8a5a28b79d4  IDFM:C01743
# 9801   IDFM:TN:SNCF:bd30df92-db61-4136-9a3d-e8a5a28b79d4  IDFM:C01743
# 9802   IDFM:TN:SNCF:bd30df92-db61-4136-9a3d-e8a5a28b79d4  IDFM:C01743
# 9803   IDFM:TN:SNCF:bd30df92-db61-4136-9a3d-e8a5a28b79d4  IDFM:C01743
# 9804   IDFM:TN:SNCF:bd30df92-db61-4136-9a3d-e8a5a28b79d4  IDFM:C01743
# 9805   IDFM:TN:SNCF:bd30df92-db61-4136-9a3d-e8a5a28b79d4  IDFM:C01743
# 9806   IDFM:TN:SNCF:bd30df92-db61-4136-9a3d-e8a5a28b79d4  IDFM:C01743
# 9807   IDFM:TN:SNCF:bd30df92-db61-4136-9a3d-e8a5a28b79d4  IDFM:C01743
# 9808   IDFM:TN:SNCF:bd30df92-db61-4136-9a3d-e8a5a28b79d4  IDFM:C01743
# 9809   IDFM:TN:SNCF:bd30df92-db61-4136-9a3d-e8a5a28b79d4  IDFM:C01743
# 9810   IDFM:TN:SNCF:bd30df92-db61-4136-9a3d-e8a5a28b79d4  IDFM:C01743
# 10078  IDFM:TN:SNCF:c0f498bd-ee7a-48b6-8672-8f5c258a296f  IDFM:C01743
# 10079  IDFM:TN:SNCF:c0f498bd-ee7a-48b6-8672-8f5c258a296f  IDFM:C01743
# 10080  IDFM:TN:SNCF:c0f498bd-ee7a-48b6-8672-8f5c258a296f  IDFM:C01743
# 10081  IDFM:TN:SNCF:c0f498bd-ee7a-48b6-8672-8f5c258a296f  IDFM:C01743
# 10082  IDFM:TN:SNCF:c0f498bd-ee7a-48b6-8672-8f5c258a296f  IDFM:C01743
# 10083  IDFM:TN:SNCF:c0f498bd-ee7a-48b6-8672-8f5c258a296f  IDFM:C01743
# 10084  IDFM:TN:SNCF:c0f498bd-ee7a-48b6-8672-8f5c258a296f  IDFM:C01743
# 10085  IDFM:TN:SNCF:c0f498bd-ee7a-48b6-8672-8f5c258a296f  IDFM:C01743
# 10086  IDFM:TN:SNCF:c0f498bd-ee7a-48b6-8672-8f5c258a296f  IDFM:C01743
# 10087  IDFM:TN:SNCF:c0f498bd-ee7a-48b6-8672-8f5c258a296f  IDFM:C01743
# 10088  IDFM:TN:SNCF:c0f498bd-ee7a-48b6-8672-8f5c258a296f  IDFM:C01743
# 10089  IDFM:TN:SNCF:c0f498bd-ee7a-48b6-8672-8f5c258a296f  IDFM:C01743
# 10090  IDFM:TN:SNCF:c0f498bd-ee7a-48b6-8672-8f5c258a296f  IDFM:C01743
# 10091  IDFM:TN:SNCF:c0f498bd-ee7a-48b6-8672-8f5c258a296f  IDFM:C01743
# 10092  IDFM:TN:SNCF:c0f498bd-ee7a-48b6-8672-8f5c258a296f  IDFM:C01743
# 10093  IDFM:TN:SNCF:c0f498bd-ee7a-48b6-8672-8f5c258a296f  IDFM:C01743
# 10094  IDFM:TN:SNCF:c0f498bd-ee7a-48b6-8672-8f5c258a296f  IDFM:C01743
# 10095  IDFM:TN:SNCF:c0f498bd-ee7a-48b6-8672-8f5c258a296f  IDFM:C01743
# 11303  IDFM:TN:SNCF:055940a2-53f4-4b65-8938-075be2b78356  IDFM:C01743
# 11304  IDFM:TN:SNCF:055940a2-53f4-4b65-8938-075be2b78356  IDFM:C01743
# 11305  IDFM:TN:SNCF:055940a2-53f4-4b65-8938-075be2b78356  IDFM:C01743
# 11306  IDFM:TN:SNCF:055940a2-53f4-4b65-8938-075be2b78356  IDFM:C01743
# 11307  IDFM:TN:SNCF:055940a2-53f4-4b65-8938-075be2b78356  IDFM:C01743
# 11308  IDFM:TN:SNCF:055940a2-53f4-4b65-8938-075be2b78356  IDFM:C01743
# 11309  IDFM:TN:SNCF:055940a2-53f4-4b65-8938-075be2b78356  IDFM:C01743
# 11310  IDFM:TN:SNCF:055940a2-53f4-4b65-8938-075be2b78356  IDFM:C01743
# 11311  IDFM:TN:SNCF:055940a2-53f4-4b65-8938-075be2b78356  IDFM:C01743
# 11312  IDFM:TN:SNCF:055940a2-53f4-4b65-8938-075be2b78356  IDFM:C01743
# 11313  IDFM:TN:SNCF:055940a2-53f4-4b65-8938-075be2b78356  IDFM:C01743
# 11314  IDFM:TN:SNCF:055940a2-53f4-4b65-8938-075be2b78356  IDFM:C01743
# 11315  IDFM:TN:SNCF:055940a2-53f4-4b65-8938-075be2b78356  IDFM:C01743
# 11316  IDFM:TN:SNCF:055940a2-53f4-4b65-8938-075be2b78356  IDFM:C01743
# 11317  IDFM:TN:SNCF:055940a2-53f4-4b65-8938-075be2b78356  IDFM:C01743
# 11318  IDFM:TN:SNCF:055940a2-53f4-4b65-8938-075be2b78356  IDFM:C01743
# 11319  IDFM:TN:SNCF:055940a2-53f4-4b65-8938-075be2b78356  IDFM:C01743
# 11320  IDFM:TN:SNCF:055940a2-53f4-4b65-8938-075be2b78356  IDFM:C01743
#
#       trip_headsign trip_short_name destination destination_id  \
# 9793           USER          USER32     Laplace     IDFM:70427
# 9794           USER          USER32     Laplace     IDFM:70427
# 9795           USER          USER32     Laplace     IDFM:70427
# 9796           USER          USER32     Laplace     IDFM:70427
# 9797           USER          USER32     Laplace     IDFM:70427
# 9798           USER          USER32     Laplace     IDFM:70427
# 9799           USER          USER32     Laplace     IDFM:70427
# 9800           USER          USER32     Laplace     IDFM:70427
# 9801           USER          USER32     Laplace     IDFM:70427
# 9802           USER          USER32     Laplace     IDFM:70427
# 9803           USER          USER32     Laplace     IDFM:70427
# 9804           USER          USER32     Laplace     IDFM:70427
# 9805           USER          USER32     Laplace     IDFM:70427
# 9806           USER          USER32     Laplace     IDFM:70427
# 9807           USER          USER32     Laplace     IDFM:70427
# 9808           USER          USER32     Laplace     IDFM:70427
# 9809           USER          USER32     Laplace     IDFM:70427
# 9810           USER          USER32     Laplace     IDFM:70427
# 10078          USER          USER28     Laplace     IDFM:70427
# 10079          USER          USER28     Laplace     IDFM:70427
# 10080          USER          USER28     Laplace     IDFM:70427
# 10081          USER          USER28     Laplace     IDFM:70427
# 10082          USER          USER28     Laplace     IDFM:70427
# 10083          USER          USER28     Laplace     IDFM:70427
# 10084          USER          USER28     Laplace     IDFM:70427
# 10085          USER          USER28     Laplace     IDFM:70427
# 10086          USER          USER28     Laplace     IDFM:70427
# 10087          USER          USER28     Laplace     IDFM:70427
# 10088          USER          USER28     Laplace     IDFM:70427
# 10089          USER          USER28     Laplace     IDFM:70427
# 10090          USER          USER28     Laplace     IDFM:70427
# 10091          USER          USER28     Laplace     IDFM:70427
# 10092          USER          USER28     Laplace     IDFM:70427
# 10093          USER          USER28     Laplace     IDFM:70427
# 10094          USER          USER28     Laplace     IDFM:70427
# 10095          USER          USER28     Laplace     IDFM:70427
# 11303          USER          USER24     Laplace     IDFM:70427
# 11304          USER          USER24     Laplace     IDFM:70427
# 11305          USER          USER24     Laplace     IDFM:70427
# 11306          USER          USER24     Laplace     IDFM:70427
# 11307          USER          USER24     Laplace     IDFM:70427
# 11308          USER          USER24     Laplace     IDFM:70427
# 11309          USER          USER24     Laplace     IDFM:70427
# 11310          USER          USER24     Laplace     IDFM:70427
# 11311          USER          USER24     Laplace     IDFM:70427
# 11312          USER          USER24     Laplace     IDFM:70427
# 11313          USER          USER24     Laplace     IDFM:70427
# 11314          USER          USER24     Laplace     IDFM:70427
# 11315          USER          USER24     Laplace     IDFM:70427
# 11316          USER          USER24     Laplace     IDFM:70427
# 11317          USER          USER24     Laplace     IDFM:70427
# 11318          USER          USER24     Laplace     IDFM:70427
# 11319          USER          USER24     Laplace     IDFM:70427
# 11320          USER          USER24     Laplace     IDFM:70427
#
#                                           origin    origin_id  time_departure  \
# 9793   Aéroport Charles de Gaulle 2 (Terminal 2)   IDFM:73699           31010
# 9794           Aéroport CDG 1 (Terminal 3) - RER   IDFM:73596           31480
# 9795                        Parc des Expositions   IDFM:73568           31790
# 9796                                  Villepinte   IDFM:73547           31910
# 9797                           Sevran Beaudottes   IDFM:73491           32080
# 9798                            Aulnay-sous-Bois   IDFM:72646           32290
# 9799                             Le Blanc-Mesnil   IDFM:72648           32420
# 9800                                      Drancy   IDFM:72652           32550
# 9801                                  Le Bourget   IDFM:72641           32710
# 9802                La Courneuve - Aubervilliers   IDFM:72598           32920
# 9803                   La Plaine Stade de France   IDFM:72211           33090
# 9804                                Gare du Nord   IDFM:71410           33420
# 9805                         Châtelet les Halles  IDFM:474151           33647
# 9806                     Saint-Michel Notre-Dame   IDFM:73620           33779
# 9807                                  Luxembourg   IDFM:71161           33891
# 9808                           Denfert-Rochereau   IDFM:71056           34059
# 9809                          Cité Universitaire   IDFM:70623           34202
# 9810                                    Gentilly   IDFM:70543           34304
# 10078  Aéroport Charles de Gaulle 2 (Terminal 2)   IDFM:73699           30650
# 10079          Aéroport CDG 1 (Terminal 3) - RER   IDFM:73596           31120
# 10080                       Parc des Expositions   IDFM:73568           31430
# 10081                                 Villepinte   IDFM:73547           31550
# 10082                          Sevran Beaudottes   IDFM:73491           31720
# 10083                           Aulnay-sous-Bois   IDFM:72646           31930
# 10084                            Le Blanc-Mesnil   IDFM:72648           32060
# 10085                                     Drancy   IDFM:72652           32190
# 10086                                 Le Bourget   IDFM:72641           32350
# 10087               La Courneuve - Aubervilliers   IDFM:72598           32560
# 10088                  La Plaine Stade de France   IDFM:72211           32730
# 10089                               Gare du Nord   IDFM:71410           33060
# 10090                        Châtelet les Halles  IDFM:474151           33287
# 10091                    Saint-Michel Notre-Dame   IDFM:73620           33419
# 10092                                 Luxembourg   IDFM:71161           33531
# 10093                          Denfert-Rochereau   IDFM:71056           33699
# 10094                         Cité Universitaire   IDFM:70623           33842
# 10095                                   Gentilly   IDFM:70543           33944
# 11303  Aéroport Charles de Gaulle 2 (Terminal 2)   IDFM:73699           30290
# 11304          Aéroport CDG 1 (Terminal 3) - RER   IDFM:73596           30760
# 11305                       Parc des Expositions   IDFM:73568           31070
# 11306                                 Villepinte   IDFM:73547           31190
# 11307                          Sevran Beaudottes   IDFM:73491           31360
# 11308                           Aulnay-sous-Bois   IDFM:72646           31570
# 11309                            Le Blanc-Mesnil   IDFM:72648           31700
# 11310                                     Drancy   IDFM:72652           31830
# 11311                                 Le Bourget   IDFM:72641           31990
# 11312               La Courneuve - Aubervilliers   IDFM:72598           32200
# 11313                  La Plaine Stade de France   IDFM:72211           32370
# 11314                               Gare du Nord   IDFM:71410           32700
# 11315                        Châtelet les Halles  IDFM:474151           32927
# 11316                    Saint-Michel Notre-Dame   IDFM:73620           33059
# 11317                                 Luxembourg   IDFM:71161           33171
# 11318                          Denfert-Rochereau   IDFM:71056           33339
# 11319                         Cité Universitaire   IDFM:70623           33482
# 11320                                   Gentilly   IDFM:70543           33584
#
#                                  arrival   arrival_id  time_arrival  \
# 9793   Aéroport CDG 1 (Terminal 3) - RER   IDFM:73596         31140
# 9794                Parc des Expositions   IDFM:73568         31760
# 9795                          Villepinte   IDFM:73547         31880
# 9796                   Sevran Beaudottes   IDFM:73491         32030
# 9797                    Aulnay-sous-Bois   IDFM:72646         32240
# 9798                     Le Blanc-Mesnil   IDFM:72648         32390
# 9799                              Drancy   IDFM:72652         32520
# 9800                          Le Bourget   IDFM:72641         32680
# 9801        La Courneuve - Aubervilliers   IDFM:72598         32890
# 9802           La Plaine Stade de France   IDFM:72211         33040
# 9803                        Gare du Nord   IDFM:71410         33360
# 9804                 Châtelet les Halles  IDFM:474151         33600
# 9805             Saint-Michel Notre-Dame   IDFM:73620         33729
# 9806                          Luxembourg   IDFM:71161         33861
# 9807                   Denfert-Rochereau   IDFM:71056         34009
# 9808                  Cité Universitaire   IDFM:70623         34167
# 9809                            Gentilly   IDFM:70543         34269
# 9810                             Laplace   IDFM:70427         34380
# 10078  Aéroport CDG 1 (Terminal 3) - RER   IDFM:73596         30780
# 10079               Parc des Expositions   IDFM:73568         31400
# 10080                         Villepinte   IDFM:73547         31520
# 10081                  Sevran Beaudottes   IDFM:73491         31670
# 10082                   Aulnay-sous-Bois   IDFM:72646         31880
# 10083                    Le Blanc-Mesnil   IDFM:72648         32030
# 10084                             Drancy   IDFM:72652         32160
# 10085                         Le Bourget   IDFM:72641         32320
# 10086       La Courneuve - Aubervilliers   IDFM:72598         32530
# 10087          La Plaine Stade de France   IDFM:72211         32680
# 10088                       Gare du Nord   IDFM:71410         33000
# 10089                Châtelet les Halles  IDFM:474151         33240
# 10090            Saint-Michel Notre-Dame   IDFM:73620         33369
# 10091                         Luxembourg   IDFM:71161         33501
# 10092                  Denfert-Rochereau   IDFM:71056         33649
# 10093                 Cité Universitaire   IDFM:70623         33807
# 10094                           Gentilly   IDFM:70543         33909
# 10095                            Laplace   IDFM:70427         34020
# 11303  Aéroport CDG 1 (Terminal 3) - RER   IDFM:73596         30420
# 11304               Parc des Expositions   IDFM:73568         31040
# 11305                         Villepinte   IDFM:73547         31160
# 11306                  Sevran Beaudottes   IDFM:73491         31310
# 11307                   Aulnay-sous-Bois   IDFM:72646         31520
# 11308                    Le Blanc-Mesnil   IDFM:72648         31670
# 11309                             Drancy   IDFM:72652         31800
# 11310                         Le Bourget   IDFM:72641         31960
# 11311       La Courneuve - Aubervilliers   IDFM:72598         32170
# 11312          La Plaine Stade de France   IDFM:72211         32320
# 11313                       Gare du Nord   IDFM:71410         32640
# 11314                Châtelet les Halles  IDFM:474151         32880
# 11315            Saint-Michel Notre-Dame   IDFM:73620         33009
# 11316                         Luxembourg   IDFM:71161         33141
# 11317                  Denfert-Rochereau   IDFM:71056         33289
# 11318                 Cité Universitaire   IDFM:70623         33447
# 11319                           Gentilly   IDFM:70543         33549
# 11320                            Laplace   IDFM:70427         33660
#
#        time_travelled  direction
# 9793              130          0
# 9794              280          0
# 9795               90          0
# 9796              120          0
# 9797              160          0
# 9798              100          0
# 9799              100          0
# 9800              130          0
# 9801              180          0
# 9802              120          0
# 9803              270          0
# 9804              180          0
# 9805               82          0
# 9806               82          0
# 9807              118          0
# 9808              108          0
# 9809               67          0
# 9810               76          0
# 10078             130          0
# 10079             280          0
# 10080              90          0
# 10081             120          0
# 10082             160          0
# 10083             100          0
# 10084             100          0
# 10085             130          0
# 10086             180          0
# 10087             120          0
# 10088             270          0
# 10089             180          0
# 10090              82          0
# 10091              82          0
# 10092             118          0
# 10093             108          0
# 10094              67          0
# 10095              76          0
# 11303             130          0
# 11304             280          0
# 11305              90          0
# 11306             120          0
# 11307             160          0
# 11308             100          0
# 11309             100          0
# 11310             130          0
# 11311             180          0
# 11312             120          0
# 11313             270          0
# 11314             180          0
# 11315              82          0
# 11316              82          0
# 11317             118          0
# 11318             108          0
# 11319              67          0
# 11320              76          0

# %%
cleaned_df.to_csv("../data/processed/Calculated_fields_theorique_.csv", encoding='utf-8-sig', sep=";", index=False)
